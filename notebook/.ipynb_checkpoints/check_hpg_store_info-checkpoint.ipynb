# %% [markdown]
# # hpg_store_info の概要把握

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# !cd
# Out:
# C:\Users\hiroshi_kuriyama\Desktop\新人研修\kaggle_Recruit\recruit_exercise\notebook

# %%
# データの読み込み
# 文字コードはUTF-8(BOMなし)
raw_hpg_store_info = pd.read_csv('../data/hpg_store_info.csv', engine='python', encoding='UTF-8')

# %% [markdown]
# ## テーブルのサイズ、要素の確認

# %% [markdown]
# データセットの概要
#
# - 4690行、5列
#
# | column | hpg_store_id | hpg_genre_name | hpg_area_name | latitude | longitude |
# | :----- | ------------ | -------------- | ------------- | -------- | --------- |
# | 意味   | hpgの店ID    | ジャンル       | 地名          | 緯度     | 経度      |
# | 型     | object       | object         | object        | float    | float     |
# | 欠損   | なし         | なし           | なし          | なし     | なし      |

# %%
# 列と行
raw_hpg_store_info.shape
# Out:
# (4690, 5)

# %%
# 型を確認
raw_hpg_store_info.dtypes
# Out:
# hpg_store_id       object
# hpg_genre_name     object
# hpg_area_name      object
# latitude          float64
# longitude         float64
# dtype: object

# %%
# 欠損の確認
raw_hpg_store_info.isnull().any(axis=0)
# Out:
# hpg_store_id      False
# hpg_genre_name    False
# hpg_area_name     False
# latitude          False
# longitude         False
# dtype: bool

# %%
raw_hpg_store_info.head()
# Out:
#            hpg_store_id  hpg_genre_name                  hpg_area_name  \
# 0  hpg_6622b62385aec8bf  Japanese style  Tōkyō-to Setagaya-ku Taishidō
# 1  hpg_e9e068dd49c5fa00  Japanese style  Tōkyō-to Setagaya-ku Taishidō
# 2  hpg_2976f7acb4b3a3bc  Japanese style  Tōkyō-to Setagaya-ku Taishidō
# 3  hpg_e51a522e098f024c  Japanese style  Tōkyō-to Setagaya-ku Taishidō
# 4  hpg_e3d0e1519894f275  Japanese style  Tōkyō-to Setagaya-ku Taishidō
#
#     latitude   longitude
# 0  35.643675  139.668221
# 1  35.643675  139.668221
# 2  35.643675  139.668221
# 3  35.643675  139.668221
# 4  35.643675  139.668221

# %%
# ランダムに行を表示
raw_hpg_store_info.sample(n=10, random_state=0)
# Out:
#               hpg_store_id            hpg_genre_name  \
# 291   hpg_41eb89ace6d5273f            Japanese style
# 2112  hpg_4e19eb463f5e5c8f     International cuisine
# 3938  hpg_7757bca6eeaa9e7c                   Seafood
# 3212  hpg_923981676bbf3cbc                  Creation
# 898   hpg_bb23953129d0d43b            Japanese style
# 4176  hpg_0fb269423e6a4c07     Spain Bar/Italian Bar
# 487   hpg_5276c62fa1593aab            Japanese style
# 1473  hpg_3a3289a9c062f404            Japanese style
# 3605  hpg_d3a6919845d25460  Japanese cuisine/Kaiseki
# 1280  hpg_5b25b871b61346ad            Japanese style
#
#                                 hpg_area_name   latitude   longitude
# 291       Shizuoka-ken Shizuoka-shi Hinodechō  34.976196  138.395167
# 2112                 Tōkyō-to Shibuya-ku None  35.659214  139.699736
# 3938          Tōkyō-to Fussa-shi Musashinodai  35.748761  139.333801
# 3212                 Tōkyō-to Toshima-ku None  35.730068  139.711742
# 898   Hiroshima-ken Fukuyama-shi Sannomaruchō  34.489677  133.362130
# 4176      Ōsaka-fu Ōsaka-shi Shinsaibashisuji  34.669514  135.501425
# 487                 Tōkyō-to Shinjuku-ku None  35.691384  139.701256
# 1473            Fukuoka-ken Fukuoka-shi Ōmiya  33.579734  130.401762
# 3605              Osaka Prefecture Osaka None  34.701519  135.498859
# 1280      Fukuoka-ken Kurume-shi Higashimachi  33.311645  130.518556

# %%
# object型の概要
raw_hpg_store_info.describe(include='O')
# Out:
#                 hpg_store_id  hpg_genre_name              hpg_area_name
# count                   4690            4690                       4690
# unique                  4690              34                        119
# top     hpg_9ad6c4b575e68b0b  Japanese style  Tōkyō-to Shinjuku-ku None
# freq                       1            1750                        257

# %%
# 数値型の概要
raw_hpg_store_info.describe()
# Out:
#           latitude    longitude
# count  4690.000000  4690.000000
# mean     35.810261   137.675816
# std       2.138755     3.197233
# min      33.311645   130.339313
# 25%      34.692109   135.498859
# 50%      35.659214   139.495733
# 75%      35.703381   139.737998
# max      43.774846   143.714585

# %% [markdown]
# ## hpg_store_id (hpgの店ID)
#
#
# ### 特徴
#   - 重複IDなし

# %%
raw_hpg_store_info['hpg_store_id'].duplicated().any(axis=0)
# Out:
# False

# %% [markdown]
# ## hpg_genre_name (hpgでの店のジャンル)
#
# ### 特徴
#
# - ジャンルは３４種類
# - Japanese Style が最も多く、全体の37%。ほとんど出現しないジャンルも複数ある。
# - 分類の粒度が不明（日本料理にもいくつかジャンルがある）

# %%
# ジャンル数を確認
raw_hpg_store_info['hpg_genre_name'].unique().size
# Out:
# 34

# %%
hpg_genre_name_dist = raw_hpg_store_info['hpg_genre_name'].value_counts()

# %%
# 出現回数を表示
print('head_5')
print(hpg_genre_name_dist.head())
print()
print('tail_5')
print(hpg_genre_name_dist.tail())
# Out:
# head_5
# Japanese style           1750
# International cuisine     700
# Creation                  410
# Seafood                   339
# Grilled meat              325
# Name: hpg_genre_name, dtype: int64
#
# tail_5
# Sweets                         2
# Spain/Mediterranean cuisine    1
# Taiwanese/Hong Kong cuisine    1
# Udon/Soba                      1
# Shanghai food                  1
# Name: hpg_genre_name, dtype: int64

# %%
# 比率をプロット
(hpg_genre_name_dist/len(raw_hpg_store_info)).plot.bar(color='steelblue')

# %% [markdown]
# ## hpg_area_name (hpgでの店の地名)
#
# ### 特徴
#
# - データ内の地名の数は119箇所
# - None None None という地名がある。
# - 13県のデータ。東京が4割以上、他の県は1割以下

# %%
# 地名の数を確認
raw_hpg_store_info['hpg_area_name'].unique().size
# Out:
# 119

# %%
hpg_area_name_dist = raw_hpg_store_info['hpg_area_name'].value_counts()

# %%
# 出現回数を表示
print('head_5')
print(hpg_area_name_dist.head())
print()
print('tail_5')
print(hpg_area_name_dist.tail())
# Out:
# head_5
# Tōkyō-to Shinjuku-ku None              257
# Tōkyō-to Chūō-ku Ginza                 198
# Hyōgo-ken Kōbe-shi None                163
# Ōsaka-fu Ōsaka-shi Shinsaibashisuji    150
# Osaka Prefecture Osaka None            145
# Name: hpg_area_name, dtype: int64
#
# tail_5
# Shizuoka-ken Fujinomiya-shi Wakanomiyachō    2
# Niigata-ken Nagaoka-shi Rokusho              1
# Hokkaidō Ashibetsu-shi None                  1
# Tōkyō-to Shinagawa-ku Koyama                 1
# Ōsaka-fu Minoo-shi Hanjo                     1
# Name: hpg_area_name, dtype: int64

# %%
# 比率をプロット
(hpg_area_name_dist/len(raw_hpg_store_info)).plot.bar(color='steelblue',figsize=(50,10))

# %% [markdown]
# ### 欠損を表す地名がある(117件)

# %%
raw_hpg_store_info.query('hpg_area_name == "None None None"').head()
# Out:
#              hpg_store_id  hpg_genre_name   hpg_area_name   latitude  \
# 651  hpg_5fea90674a2185a0  Japanese style  None None None  35.703381
# 652  hpg_03d5b644f759a72a  Japanese style  None None None  35.703381
# 653  hpg_0bf592f4c532d843  Japanese style  None None None  35.703381
# 654  hpg_a11c66d3ce9a8c13  Japanese style  None None None  35.703381
# 655  hpg_5cb7bac2842ca8f5  Japanese style  None None None  35.703381
#
#       longitude
# 651  139.660343
# 652  139.660343
# 653  139.660343
# 654  139.660343
# 655  139.660343

# %% [markdown]
# ### 県名レベルでの集計

# %%
hpg_pref_name = raw_hpg_store_info['hpg_area_name'].apply(lambda x:x.split(' ')[0])

# %%
# 県の数
hpg_pref_name.unique().size
# Out:
# 13

# %%
hpg_pref_name_dist = hpg_pref_name.value_counts()

# %%
# 出現回数を表示
print('head_5')
print(hpg_pref_name_dist.head())
print()
print('tail_5')
print(hpg_pref_name_dist.tail())
# Out:
# head_5
# Tōkyō-to       2076
# Ōsaka-fu        514
# Fukuoka-ken     380
# Hyōgo-ken       331
# Hokkaidō        298
# Name: hpg_area_name, dtype: int64
#
# tail_5
# Niigata-ken     142
# Miyagi-ken      139
# None            117
# Kanagawa-ken     61
# Saitama-ken      11
# Name: hpg_area_name, dtype: int64

# %%
# 比率をプロット
(hpg_pref_name_dist/len(raw_hpg_store_info)).plot.bar(color='steelblue')

# %% [markdown]
# ## latitude, longitude
#
# ### 特徴
#
# -
# -

# %%
# 再掲
# 数値型の概要
raw_hpg_store_info.describe()
# Out:
#           latitude    longitude
# count  4690.000000  4690.000000
# mean     35.810261   137.675816
# std       2.138755     3.197233
# min      33.311645   130.339313
# 25%      34.692109   135.498859
# 50%      35.659214   139.495733
# 75%      35.703381   139.737998
# max      43.774846   143.714585

# %%
raw_hpg_store_info.plot.scatter(x='longitude', y='latitude')

# %% [markdown]
# ### 東西南北の最端地点

# %%
# 最北
raw_hpg_store_info.sort_values(by='longitude').tail(1)
# Out:
#               hpg_store_id         hpg_genre_name  \
# 2430  hpg_55629e3b63f4ae74  International cuisine
#
#                       hpg_area_name   latitude   longitude
# 2430  Hokkaidō Tokachi-gun Kawakami  43.129879  143.714585

# %%
# 最南
raw_hpg_store_info.sort_values(by='longitude').head(1)
# Out:
#               hpg_store_id hpg_genre_name                      hpg_area_name  \
# 3040  hpg_5fc79c99232bc6eb       Creation  Fukuoka-ken Fukuoka-shi Minamishō
#
#        latitude   longitude
# 3040  33.576379  130.339313

# %%
# 最東端
raw_hpg_store_info.sort_values(by='latitude').tail(1)
# Out:
#               hpg_store_id  hpg_genre_name  \
# 1642  hpg_357ae60e6bee336b  Japanese style
#
#                             hpg_area_name   latitude   longitude
# 1642  Hokkaidō Asahikawa-shi Higashi 6 Jō  43.774846  142.377403

# %%
# 最西
raw_hpg_store_info.sort_values(by='latitude').head(1)
# Out:
#               hpg_store_id hpg_genre_name  \
# 2934  hpg_0640338d8f68c004   Grilled meat
#
#                             hpg_area_name   latitude   longitude
# 2934  Fukuoka-ken Kurume-shi Higashimachi  33.311645  130.518556

# %% [markdown]
# ### ジャンルと地名の相関

# %%
# ジャンルと地名でピボットテーブル作成
hpg_genre_area_pivot = raw_hpg_store_info.pivot_table(values='hpg_store_id', index='hpg_genre_name', columns='hpg_area_name', aggfunc=lambda x: x.value_counts().count())
# NaNに0を代入
hpg_genre_area_pivot[hpg_genre_area_pivot.isnull()] = 0
# ヒートマップを出力
sns.heatmap(hpg_genre_area_pivot)

# %% [markdown]
# #### 県ごとに見てみる

# %%
raw_hpg_store_info_pref = pd.concat([raw_hpg_store_info, hpg_pref_name], axis=1)

# %%
raw_hpg_store_info_pref.columns = ['hpg_store_id', 'hpg_genre_name', 'hpg_area_name', 'latitude',
       'longitude', 'hpg_fref_name']

# %%
raw_hpg_store_info_pref.head()
# Out:
#            hpg_store_id  hpg_genre_name                  hpg_area_name  \
# 0  hpg_6622b62385aec8bf  Japanese style  Tōkyō-to Setagaya-ku Taishidō
# 1  hpg_e9e068dd49c5fa00  Japanese style  Tōkyō-to Setagaya-ku Taishidō
# 2  hpg_2976f7acb4b3a3bc  Japanese style  Tōkyō-to Setagaya-ku Taishidō
# 3  hpg_e51a522e098f024c  Japanese style  Tōkyō-to Setagaya-ku Taishidō
# 4  hpg_e3d0e1519894f275  Japanese style  Tōkyō-to Setagaya-ku Taishidō
#
#     latitude   longitude hpg_fref_name
# 0  35.643675  139.668221      Tōkyō-to
# 1  35.643675  139.668221      Tōkyō-to
# 2  35.643675  139.668221      Tōkyō-to
# 3  35.643675  139.668221      Tōkyō-to
# 4  35.643675  139.668221      Tōkyō-to

# %%
# ジャンルと地名でピボットテーブル作成
hpg_genre_area_pivot = raw_hpg_store_info_pref.pivot_table(values='hpg_store_id', index='hpg_genre_name', columns='hpg_fref_name', aggfunc=lambda x: x.value_counts().count())
# NaNに0を代入
hpg_genre_area_pivot[hpg_genre_area_pivot.isnull()] = 0
# ヒートマップを出力
sns.heatmap(hpg_genre_area_pivot)
